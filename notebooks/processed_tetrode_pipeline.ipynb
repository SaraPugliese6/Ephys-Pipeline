# %%
from pathlib import Path

import spikeinterface as si
import spikeinterface.preprocessing as spre
import spikeinterface.widgets as sw
import numpy as np
import pynapple as nap

import matplotlib.pyplot as plt

# %%
# %matplotlib widget
si.set_global_job_kwargs(n_jobs=0.5, chunk_duration="1s", progress_bar=True)

# %%
data = nap.load_file("../data/processed/sub-KM131_ses-20180116T184757_behavior+ecephys+image.nwb")
data

units = data['units']   # TsGroup
trials = data['trials']
# Out:
# sub-KM131_ses-20180116T184757_behavior+ecephys+image
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━┑
# │ Keys                                       │ Type        │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┥
# │ units                                      │ TsGroup     │
# │ trials                                     │ IntervalSet │
# │ contacts_by_whisker_C3                     │ IntervalSet │
# │ contacts_by_whisker_C2                     │ IntervalSet │
# │ contacts_by_whisker_C1                     │ IntervalSet │
# │ contacts_by_whisker_C0                     │ IntervalSet │
# │ rewards/right                              │ Tsd         │
# │ rewards/left                               │ Tsd         │
# │ raw_position_whisker_C3/marker_7           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_6           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_5           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_4           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_3           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_2           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_1           │ TsdFrame    │
# │ raw_position_whisker_C3/marker_0           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_7           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_6           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_5           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_4           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_3           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_2           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_1           │ TsdFrame    │
# │ raw_position_whisker_C2/marker_0           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_7           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_6           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_5           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_4           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_3           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_2           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_1           │ TsdFrame    │
# │ raw_position_whisker_C1/marker_0           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_7           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_6           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_5           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_4           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_3           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_2           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_1           │ TsdFrame    │
# │ raw_position_whisker_C0/marker_0           │ TsdFrame    │
# │ processed_position_whisker_C3/tip_y        │ Tsd         │
# │ processed_position_whisker_C3/tip_x        │ Tsd         │
# │ processed_position_whisker_C3/interpolated │ Tsd         │
# │ processed_position_whisker_C3/bend         │ Tsd         │
# │ processed_position_whisker_C3/base_y       │ Tsd         │
# │ processed_position_whisker_C3/base_x       │ Tsd         │
# │ processed_position_whisker_C3/angle        │ Tsd         │
# │ processed_position_whisker_C2/tip_y        │ Tsd         │
# │ processed_position_whisker_C2/tip_x        │ Tsd         │
# │ processed_position_whisker_C2/interpolated │ Tsd         │
# │ processed_position_whisker_C2/bend         │ Tsd         │
# │ processed_position_whisker_C2/base_y       │ Tsd         │
# │ processed_position_whisker_C2/base_x       │ Tsd         │
# │ processed_position_whisker_C2/angle        │ Tsd         │
# │ processed_position_whisker_C1/tip_y        │ Tsd         │
# │ processed_position_whisker_C1/tip_x        │ Tsd         │
# │ processed_position_whisker_C1/interpolated │ Tsd         │
# │ processed_position_whisker_C1/bend         │ Tsd         │
# │ processed_position_whisker_C1/base_y       │ Tsd         │
# │ processed_position_whisker_C1/base_x       │ Tsd         │
# │ processed_position_whisker_C1/angle        │ Tsd         │
# │ processed_position_whisker_C0/tip_y        │ Tsd         │
# │ processed_position_whisker_C0/tip_x        │ Tsd         │
# │ processed_position_whisker_C0/interpolated │ Tsd         │
# │ processed_position_whisker_C0/bend         │ Tsd         │
# │ processed_position_whisker_C0/base_y       │ Tsd         │
# │ processed_position_whisker_C0/base_x       │ Tsd         │
# │ processed_position_whisker_C0/angle        │ Tsd         │
# │ licks/right                                │ Tsd         │
# │ licks/left                                 │ Tsd         │
# │ extracellular array recording              │ TsdFrame    │
# │ behavioral video                           │ TsdTensor   │
# ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━┙
